# %% [markdown]
# amazon web scraping project

# %%
#importing libraries
from bs4 import BeautifulSoup
import requests
import smtplib #not compulsary - use to send email to yourself
import time
import datetime

# %% [markdown]
# #connecting to website
# url='https://www.amazon.com/Funny-Data-Systems-Business-Analyst/dp/B07FNW9FGJ?customId=B0752XJYNL&dchild=1&keywords=data+analyst+tshirt&qid=1626655184&sr=8-3&th=1'
# #this header part we do not need to know ,it depends on the sys u are working on and half of the prt u will get on https://httpbin.org/get (user agreement).
# headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36 Edg/135.0.0.0", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}
# page=requests.get(url,headers=headers)
# soup1=BeautifulSoup(page.content,'html.parser')
# soup2 = BeautifulSoup(soup1.prettify(),'html.parser') #kind of upgrading soup 1 to look good
# title=soup2.find(id='title')
# #price=soup2.find(id='')
# print(title)

# %% [markdown]
# URL = 'https://www.amazon.com/Funny-Data-Systems-Business-Analyst/dp/B07FNW9FGJ/ref=sr_1_3?dchild=1&keywords=data%2Banalyst%2Btshirt&qid=1626655184&sr=8-3&customId=B0752XJYNL&th=1'
#
# headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36 Edg/135.0.0.0", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}
#
# page = requests.get(URL, headers=headers)
#
# soup1 = BeautifulSoup(page.content, "html.parser")
#
# soup2 = BeautifulSoup(soup1.prettify(), "html.parser")
#
# title = soup2.find(id='productTitle').get_text()
#
# price = soup2.find(id='priceblock_ourprice').get_text()
# #this is not working for me so i am gonna choose different product

# %%
#connecting to website
url='https://www.amazon.in/iPhone-16-Pro-128-GB/dp/B0DGJH94KM?crid=3J6FW27MSGBS8&dib=eyJ2IjoiMSJ9.GtBrEHXvJPyueQwyhjY_aPQy6btsGIJRIWrQhobuAnUYxc61NR9Qh-S3XchUD4-CW3eQ50vF5lxYjDbMybKPvTtAG1lAiSmgHseC_z-SilCPK4js-zQv4KL0jrm2e3gaiCIvPttk2VNBXxKK-3ckwxbzrubq4KSaIvEgoZsGeSH1OUz1q7JXVbCgjIoLvTLvX4p-s-zBNUUf6Khu-4T-J2qQA9dLdhbq1gVuXAJucsA.TXE4UsA8xpnpTzRNy-xPf5SzbyxxN8PxY5SjY15ZAdU&dib_tag=se&keywords=iphone&qid=1745334861&sprefix=iphone%2Caps%2C243&sr=8-5&th=1'
#this header part we do not need to know ,it depends on the sys u are working on and half of the prt u will get on https://httpbin.org/get (user agreement).
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36 Edg/135.0.0.0", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}
page=requests.get(url,headers=headers)
soup1=BeautifulSoup(page.content,'html.parser')
soup2 = BeautifulSoup(soup1.prettify(),'html.parser') #kind of upgrading soup 1 to look good
title = soup2.find(id='productTitle').get_text()
price = soup2.find(id='corePriceDisplay_desktop_feature_div').get_text()
print(title)
print(price)
#finally it worked
# Out:
#             iPhone 16 Pro 128 GB: 5G Mobile Phone with Camera Control, 4K 120 fps Dolby Vision and a Huge Leap in Battery Life. Works with AirPods; Natural Titanium
#
#
#
#
#
#               ₹1,12,900.00 with 6 percent savings
#
#
#               -6%
#
#
#
#
#
#
#                 ₹
#
#
#                 1,12,900
#
#
#
#
#
#
#
#
#
#
#                 M.R.P.: ₹1,19,900.00
#
#
#                 M.R.P.:
#
#
#                   ₹1,19,900
#
#
#                   ₹1,19,900

# %%
title=title.strip()[:20]
price=price.strip()[1:12]
print(price)
# Out:
# 1,12,900.00

# %%
import datetime
today=datetime.date.today()
print(today)
# Out:
# 2025-04-22

# %%
import csv
header=['title','price','date']
data=[title,price,today] #here we are changing datatype from string to list , type of data do plays an impact on this kind of work

with open('Amazon_webscraper_dataset.csv', 'w',newline='',encoding='UTF8') as f: #cause of newline when we insert a data it won't have space in b/w
    writer=csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
#now we don't want to open the file again and again so we'll use pandas
import pandas as pd
df = pd.read_csv(r"C:\Users\kesha\da\Amazon_webscraper_dataset.csv")
df
# Out:
#                   title        price        date
# 0  iPhone 16 Pro 128 GB  1,12,900.00  2025-04-22
# 1  iPhone 16 Pro 128 GB  1,12,900.00  2025-04-22

# %%
#now we are appending data
with open('Amazon_webscraper_dataset.csv', 'a+',newline='',encoding='UTF8') as f: #cause of newline when we insert a data it won't have space in b/w
    writer=csv.writer(f)    #now using a+
    writer.writerow(data)
#now since data is not changed same data will be inserted again as we can see above

# %%
#now we don't want to repeat this agin and agin to add data so we'll automate it , so first we'll create a function 

def check_price():
    
    url='https://www.amazon.in/iPhone-16-Pro-128-GB/dp/B0DGJH94KM?crid=3J6FW27MSGBS8&dib=eyJ2IjoiMSJ9.GtBrEHXvJPyueQwyhjY_aPQy6btsGIJRIWrQhobuAnUYxc61NR9Qh-S3XchUD4-CW3eQ50vF5lxYjDbMybKPvTtAG1lAiSmgHseC_z-SilCPK4js-zQv4KL0jrm2e3gaiCIvPttk2VNBXxKK-3ckwxbzrubq4KSaIvEgoZsGeSH1OUz1q7JXVbCgjIoLvTLvX4p-s-zBNUUf6Khu-4T-J2qQA9dLdhbq1gVuXAJucsA.TXE4UsA8xpnpTzRNy-xPf5SzbyxxN8PxY5SjY15ZAdU&dib_tag=se&keywords=iphone&qid=1745334861&sprefix=iphone%2Caps%2C243&sr=8-5&th=1'
    
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36 Edg/135.0.0.0", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}
    
    page=requests.get(url,headers=headers)
    
    soup1=BeautifulSoup(page.content,'html.parser')
    
    soup2 = BeautifulSoup(soup1.prettify(),'html.parser')
    
    title = soup2.find(id='productTitle').get_text()
    
    price = soup2.find(id='corePriceDisplay_desktop_feature_div').get_text()
    
    import datetime
    today=datetime.date.today()

    title=title.strip()[:20]
    price=price.strip()[1:12]
    
    import csv
    
    header=['title','price','date']
    data=[title,price,today]
    
    with open('Amazon_webscraper_dataset.csv', 'w',newline='',encoding='UTF8') as f: 
        writer=csv.writer(f)
        writer.writerow(data)

# %%
while(True):
    check_price()
    time.sleep(5) #now it will run this code every 5 sec , change 5 with 86400 then it'll check every day
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[154], line 3
#       1 while(True):
#       2     check_price()
# ----> 3     time.sleep(5)
#
# KeyboardInterrupt:

# %%
#before running this first terminate the above code
import pandas as pd
df = pd.read_csv(r"C:\Users\kesha\da\Amazon_webscraper_dataset.csv")
print(df)
# Out:
# Empty DataFrame
# Columns: [iPhone 16 Pro 128 GB, 1,12,900.00, 2025-04-22]
# Index: []
